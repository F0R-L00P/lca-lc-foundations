# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# In a fictional setting, the capital of The Moon is Seleneport.
#
# - Location: Built along the sunlit rim of Shackleton Crater in the lunar south pole region. The city sits where daylight lingers longest, with vast solar farms and ice deposits nearby for power and life support.
#
# - Government: The seat of the Lunar Confederation’s Central Directorate. It houses the Lunar Assembly, the Solar Court, and the Directorate’s executive chambers—an arrangement designed for a polity spanning surface habitats and orbital outposts.
#
# - Architecture: A harmony of arched glass and reinforced regolith. Arcology towers rise around a centerpiece dome called the Aurelia Spire, which doubles as a communications node. The Lantern Quarter glows with lantern-like lamps and art glass, while subterranean networks link water ice wells, power basins, and transit hubs.
#
# - Notable districts and landmarks:
#   - Lantern Quarter: markets, galleries, and performance halls that celebrate Earth-Moon cultural fusion.
#   - The Glass Sea: a vast expanse of reflective solar farms set in a crater floor, turning sunlight into liquid energy.
#   - The Gate: monumental access point for shuttles and vactrains to lunar orbit.
#   - The Archives of Mare Cognitio: a vast library of lunar science, exploration logs, and human memory.
#
# - Economy: Energy exporter to Earth and space habitats, with mining of high-grade regolith, ice for life support, and advanced habitat technologies manufactured in-city.
#
# - Culture: A blend of generations of Earth expatriates and indigenous lunar engineers. Long cycles of day and night shape work-rest rhythms; art and music often revolve around light, shadow, and resonance. Festivals mark sunrise at the rim and the rare Earthlight events.
#
# - Transportation: Vacuum-tube maglev corridors, pressurized ground transit within domes, and elevator shafts that rise to orbital docking rings. Private photonic shuttles glide between districts.
#
# If you’d like, I can craft a scene set in Seleneport or sketch a map layout for its districts.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'OIP.png', 'type': 'image/png', 'size': 520078, 'content': <memory at 0x0000020CC6CAE440>, 'last_modified': datetime.datetime(2025, 12, 21, 21, 49, 37, 771000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# You’re looking at Solis Prime, the capital city of Astraea. It sits in the cradle of a colossal crater on a desert world where two moons drift overhead and a great blue planet hangs in the sky like a distant beacon. Here’s what makes the capital unique.
#
# - Geography and layout
#   - The city unfolds in terraces along the crater’s inner rim, with a funneling gradient from sun-baked basalt terraces at the edge to a shaded, water-fringe at the crater floor.
#   - A network of bridges, glass stairs, and magnetic trams climbs the rock faces, linking districts that cling to the sides of the crater and in the center where the ground pressure is most stable.
#   - Solar farms and geothermal vents nestle in the crater’s volcanic grit, keeping Solis Prime lit and warm even through dust storms.
#
# - Architecture
#   - Buildings mix basalt, tempered glass, and living polymers that tint to control heat and glare. Facades shimmer amber and copper, reflecting the sun in shifting bands as you walk.
#   - The city’s spine is a continuous arc of towers called the Glass Spine, a vertical city within a beam of light that rises from the crater floor toward the rim.
#   - Much of life happens under canopies and in shaded courtyards—people live in a world of controlled light and cooling breezes, with vents and wind towers to channel the thin atmosphere.
#
# - Government and society
#   - The ruling body is the Meridian Council, a rotating assembly drawn from every district. Decisions are reached in a dome called the Prism, where holographic oracles project possible futures.
#   - Citizens are known as Solarii—engineers, traders, and archivists who prize practical knowledge, solar stewardship, and memory as a public resource.
#   - There’s a mature civil society with a strong tradition of open archives; data and memory are treated as public trust, not private property.
#
# - Economy and technology
#   - The city is powered by a hybrid grid: solar collectors along the rim, solar-hydro hybrids at the floor, and micro-geothermal loops beneath the basalt.
#   - Transport relies on magnetic rails, hover-pods, and wind-assisted skims that glide along the crater’s edges—efficient for a harsh, dust-prone environment.
#   - The Archive of Echoes, a monumental library and data repository, stores the planet’s history, maps, and astronomical records in crystalline storage.
#
# - Culture and daily life
#   - Life revolves around the dawn and the cool of the crater floor. Markets bustle in shadowed courtyards where music, digital graffiti, and aroma-tagged foods mingle.
#   - Festivals honor the two moons and the star-streaks that appear when the solar glare softens. The “Festival of Echoes” features performances that ripple through the city’s acoustic chambers.
#   - Food tends to be sun-dried or hydroponically grown in terraced gardens; spice and resin farmers export rare flavors to off-world colonies.
#
# - Landmarks and districts
#   - The Cradle District: industrial heart near the crater floor where energy plants and workshops hum day and night.
#   - The Glass Spine: a soaring corridor of towers that acts as the city’s nerve center and ceremonial pathway.
#   - The Echo Market: an evening bazaar under shaded arches where traders barter memory chips, water rations, and photonic art.
#   - The Archive of Echoes: a glowing crystalline precinct where holographic histories are stored and studied.
#   - The Crown: the Meridian Council’s seat, a domed citadel perched at the rim with panoramic views of the two moons and the blue world beyond.
#
# - Challenges and threats
#   - Water scarcity and dust storms test the city’s resilience; the Meridian Council often negotiates with off-world hydro-miners and orbital freighters for supplies.
#   - Solar storms and atmospheric leaks require constant maintenance of the reflective and cooling surfaces.
#   - Political intrigue threads through the corridors—control of memory, access to the Archive, and influence over the Prism can sway power.
#
# If you’d like, I can tailor Solis Prime to a story vibe—opulent, dystopian, hopeful, or ancient-tech. I can also write a scene set in a specific district (e.g., a tense council meeting in the Prism, or a night market in the Echo Market) or sketch a backstory for its founding and key figures.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████| 50/50 [00:05<00:00,  9.87it/s]
# Done.

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# I can help analyze the audio file you provided. Please give me a moment to listen and assess the content.
